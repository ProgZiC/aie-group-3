# %%
# # HW10-11: Computer Vision in PyTorch
# ### 1. Импорты, seed, устройство

import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import json
import os
from tqdm import tqdm

# Фиксация seed для воспроизводимости
seed = 42
torch.manual_seed(seed)
np.random.seed(seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)

# Устройство
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Создание папок для артефактов
os.makedirs("artifacts/figures", exist_ok=True)


# ### 2. Часть A: классификация CIFAR100


# #### 2.1. Загрузка данных


# Базовые трансформации для CNN (32x32)
transform_base_cnn = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# Аугментации для CNN
transform_aug_cnn = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# Трансформации для ResNet (224x224)
transform_base_resnet = transforms.Compose([
    transforms.Resize(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

transform_aug_resnet = transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# Загрузка CIFAR100
full_train_cnn = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transform_base_cnn)
test_dataset_cnn = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=transform_base_cnn)

full_train_resnet = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transform_base_resnet)
test_dataset_resnet = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=transform_base_resnet)

# Разделение train на train (80%) и val (20%) для CNN
train_size = int(0.8 * len(full_train_cnn))
val_size = len(full_train_cnn) - train_size
train_dataset_cnn, val_dataset_cnn = random_split(full_train_cnn, [train_size, val_size],
                                                  generator=torch.Generator().manual_seed(seed))

# Для аугментированного обучения CNN
full_train_aug_cnn = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transform_aug_cnn)
train_dataset_aug_cnn, _ = random_split(full_train_aug_cnn, [train_size, val_size],
                                        generator=torch.Generator().manual_seed(seed))

# Разделение для ResNet (те же индексы, чтобы split был одинаковым)
indices = list(range(len(full_train_resnet)))
train_indices, val_indices = indices[:train_size], indices[train_size:]
train_dataset_resnet = torch.utils.data.Subset(full_train_resnet, train_indices)
val_dataset_resnet = torch.utils.data.Subset(full_train_resnet, val_indices)

# Для аугментированного обучения ResNet
full_train_aug_resnet = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transform_aug_resnet)
train_dataset_aug_resnet = torch.utils.data.Subset(full_train_aug_resnet, train_indices)

# DataLoaders
batch_size = 64
train_loader_cnn = DataLoader(train_dataset_cnn, batch_size=batch_size, shuffle=True, num_workers=2)
val_loader_cnn = DataLoader(val_dataset_cnn, batch_size=batch_size, shuffle=False, num_workers=2)
test_loader_cnn = DataLoader(test_dataset_cnn, batch_size=batch_size, shuffle=False, num_workers=2)
train_loader_aug_cnn = DataLoader(train_dataset_aug_cnn, batch_size=batch_size, shuffle=True, num_workers=2)

train_loader_resnet = DataLoader(train_dataset_resnet, batch_size=batch_size, shuffle=True, num_workers=2)
val_loader_resnet = DataLoader(val_dataset_resnet, batch_size=batch_size, shuffle=False, num_workers=2)
test_loader_resnet = DataLoader(test_dataset_resnet, batch_size=batch_size, shuffle=False, num_workers=2)
train_loader_aug_resnet = DataLoader(train_dataset_aug_resnet, batch_size=batch_size, shuffle=True, num_workers=2)


# #### 2.2. Sanity‑check


images, labels = next(iter(train_loader_cnn))
print(f"CNN train batch shape: {images.shape}, labels: {labels.shape}")

# Визуализация нескольких изображений
def imshow(img, title=None):
    img = img.permute(1,2,0).numpy()
    img = img * np.array([0.229, 0.224, 0.225]) + np.array([0.485, 0.456, 0.406])
    img = np.clip(img, 0, 1)
    plt.imshow(img)
    if title:
        plt.title(title)
    plt.axis('off')

fig, axes = plt.subplots(1, 5, figsize=(12,3))
for i in range(5):
    img = images[i]
    img = img.permute(1,2,0).numpy()
    img = img * np.array([0.229, 0.224, 0.225]) + np.array([0.485, 0.456, 0.406])
    img = np.clip(img, 0, 1)
    axes[i].imshow(img)
    axes[i].set_title(f"Label: {labels[i].item()}")
    axes[i].axis('off')
plt.tight_layout()
plt.show()


# #### 2.3. Простая CNN


class SimpleCNN(nn.Module):
    def __init__(self, num_classes=100):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 32, 3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, 3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, 3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        # После трёх пулингов: 32 -> 16 -> 8 -> 4
        self.fc1 = nn.Linear(128 * 4 * 4, 512)
        self.fc2 = nn.Linear(512, num_classes)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        x = self.pool(self.relu(self.conv1(x)))
        x = self.pool(self.relu(self.conv2(x)))
        x = self.pool(self.relu(self.conv3(x)))
        x = x.view(x.size(0), -1)
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x


# #### 2.4. Функции обучения и оценки


def train_one_epoch(model, loader, optimizer, criterion, device):
    model.train()
    total_loss = 0
    correct = 0
    total = 0
    for inputs, targets in tqdm(loader, desc="Training"):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * inputs.size(0)
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
    return total_loss / total, correct / total

def evaluate(model, loader, criterion, device):
    model.eval()
    total_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, targets in tqdm(loader, desc="Evaluating"):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            total_loss += loss.item() * inputs.size(0)
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()
    return total_loss / total, correct / total

def run_experiment(model, train_loader, val_loader, epochs=20, lr=0.001, save_name=None):
    model = model.to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)
    best_val_acc = 0
    history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': []}
    for epoch in range(epochs):
        train_loss, train_acc = train_one_epoch(model, train_loader, optimizer, criterion, device)
        val_loss, val_acc = evaluate(model, val_loader, criterion, device)
        history['train_loss'].append(train_loss)
        history['train_acc'].append(train_acc)
        history['val_loss'].append(val_loss)
        history['val_acc'].append(val_acc)
        print(f"Epoch {epoch+1}: train_loss={train_loss:.4f}, train_acc={train_acc:.4f}, val_loss={val_loss:.4f}, val_acc={val_acc:.4f}")
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            if save_name:
                torch.save(model.state_dict(), f"{save_name}.pt")
    return history, best_val_acc


# #### 2.5. Эксперименты C1–C4


epochs = 20
lr = 0.001

# C1: SimpleCNN без аугментаций
model_c1 = SimpleCNN()
hist_c1, best_val_c1 = run_experiment(model_c1, train_loader_cnn, val_loader_cnn, epochs, lr, save_name="best_c1")
print(f"C1 best val acc: {best_val_c1:.4f}")

# C2: SimpleCNN с аугментациями
model_c2 = SimpleCNN()
hist_c2, best_val_c2 = run_experiment(model_c2, train_loader_aug_cnn, val_loader_cnn, epochs, lr, save_name="best_c2")
print(f"C2 best val acc: {best_val_c2:.4f}")

# C3: ResNet18 с замороженным backbone
model_c3 = torchvision.models.resnet18(pretrained=True)
for param in model_c3.parameters():
    param.requires_grad = False
num_ftrs = model_c3.fc.in_features
model_c3.fc = nn.Linear(num_ftrs, 100)
hist_c3, best_val_c3 = run_experiment(model_c3, train_loader_resnet, val_loader_resnet, epochs, lr, save_name="best_c3")
print(f"C3 best val acc: {best_val_c3:.4f}")

# C4: ResNet18 с дообучением последних слоёв (layer4 + fc)
model_c4 = torchvision.models.resnet18(pretrained=True)
for param in model_c4.parameters():
    param.requires_grad = False
for param in model_c4.layer4.parameters():
    param.requires_grad = True
model_c4.fc = nn.Linear(num_ftrs, 100)
model_c4.fc.requires_grad = True
hist_c4, best_val_c4 = run_experiment(model_c4, train_loader_resnet, val_loader_resnet, epochs, lr, save_name="best_c4")
print(f"C4 best val acc: {best_val_c4:.4f}")


# #### 2.6. Выбор лучшей модели по валидации и тестирование


best_val_accs = {
    "C1": best_val_c1,
    "C2": best_val_c2,
    "C3": best_val_c3,
    "C4": best_val_c4
}
best_model_id = max(best_val_accs, key=best_val_accs.get)
print(f"Best model: {best_model_id} with val_acc = {best_val_accs[best_model_id]:.4f}")

# Загружаем лучшие веса и тестируем
if best_model_id in ["C1", "C2"]:
    model_best = SimpleCNN()
    model_best.load_state_dict(torch.load(f"best_{best_model_id.lower()}.pt"))
    test_loader = test_loader_cnn
else:
    model_best = torchvision.models.resnet18(pretrained=False)
    num_ftrs = model_best.fc.in_features
    model_best.fc = nn.Linear(num_ftrs, 100)
    if best_model_id == "C3":
        for param in model_best.parameters():
            param.requires_grad = False
    else:  # C4
        for param in model_best.parameters():
            param.requires_grad = False
        for param in model_best.layer4.parameters():
            param.requires_grad = True
        model_best.fc.requires_grad = True
    model_best.load_state_dict(torch.load(f"best_{best_model_id.lower()}.pt"))
    test_loader = test_loader_resnet

model_best = model_best.to(device)
test_loss, test_acc = evaluate(model_best, test_loader, nn.CrossEntropyLoss(), device)
print(f"Test accuracy of best model: {test_acc:.4f}")


# #### 2.7. Сохранение артефактов классификации


# Создаём DataFrame для runs.csv
results = []
for exp in ["C1","C2","C3","C4"]:
    val_acc = best_val_accs[exp]
    results.append({
        "experiment_id": exp,
        "task": "classification",
        "dataset": "CIFAR100",
        "seed": seed,
        "model_summary": "SimpleCNN" if exp in ["C1","C2"] else "ResNet18",
        "optimizer": "Adam",
        "lr": lr,
        "epochs_trained": epochs,
        "best_val_accuracy": val_acc,
        "test_accuracy": test_acc if exp == best_model_id else None,
        "precision": None,
        "recall": None,
        "mean_iou": None,
        "notes": ""
    })
df_results = pd.DataFrame(results)

# Сохраняем best_classifier.pt и конфиг
torch.save(model_best.state_dict(), "artifacts/best_classifier.pt")
config = {
    "dataset": "CIFAR100",
    "architecture": "ResNet18" if best_model_id in ["C3","C4"] else "SimpleCNN",
    "transforms": {
        "train": "transform_aug_cnn" if best_model_id == "C2" else ("transform_aug_resnet" if best_model_id == "C4" else "transform_base_cnn"),
        "val": "transform_base_cnn" if best_model_id in ["C1","C2"] else "transform_base_resnet",
        "test": "transform_base_cnn" if best_model_id in ["C1","C2"] else "transform_base_resnet"
    },
    "seed": seed,
    "hyperparameters": {
        "lr": lr,
        "epochs": epochs,
        "batch_size": batch_size,
        "optimizer": "Adam"
    }
}
with open("artifacts/best_classifier_config.json", "w") as f:
    json.dump(config, f, indent=2)

# График кривых лучшего прогона
if best_model_id == "C1":
    best_hist = hist_c1
elif best_model_id == "C2":
    best_hist = hist_c2
elif best_model_id == "C3":
    best_hist = hist_c3
else:
    best_hist = hist_c4

plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.plot(best_hist['train_loss'], label='train loss')
plt.plot(best_hist['val_loss'], label='val loss')
plt.legend()
plt.title('Loss curves')
plt.subplot(1,2,2)
plt.plot(best_hist['train_acc'], label='train acc')
plt.plot(best_hist['val_acc'], label='val acc')
plt.legend()
plt.title('Accuracy curves')
plt.savefig("artifacts/figures/classification_curves_best.png")
plt.show()

# Сравнение C1-C4
plt.figure()
plt.bar(list(best_val_accs.keys()), list(best_val_accs.values()), color=['blue','green','orange','red'])
plt.ylabel('Best validation accuracy')
plt.title('Comparison of experiments C1-C4')
plt.savefig("artifacts/figures/classification_compare.png")
plt.show()

# Визуализация аугментаций (на примере CNN аугментаций)
def show_augmentations(dataset, num_images=5):
    fig, axes = plt.subplots(1, num_images, figsize=(15,3))
    for i in range(num_images):
        img, _ = dataset[i]
        img = img.permute(1,2,0).numpy()
        img = img * np.array([0.229, 0.224, 0.225]) + np.array([0.485, 0.456, 0.406])
        img = np.clip(img, 0, 1)
        axes[i].imshow(img)
        axes[i].axis('off')
    plt.savefig("artifacts/figures/augmentations_preview.png")
    plt.show()

show_augmentations(train_dataset_aug_cnn)


# ### 3. Часть B: детекция на Pascal VOC


# #### 3.1. Загрузка датасета и модели


# Загружаем предобученную Faster R-CNN
model_det = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
model_det.eval()
model_det.to(device)

# Загружаем датасет VOC Detection 
train_det = torchvision.datasets.VOCDetection(root='./data', year='2012', image_set='train', download=True)
val_det = torchvision.datasets.VOCDetection(root='./data', year='2012', image_set='val', download=True)

# Для sanity-check
sample_img, sample_target = val_det[0]
print(f"Sample image size: {sample_img.size}")
print(f"Sample target keys: {sample_target.keys()}")


# #### 3.2. Вспомогательные функции


def compute_iou(boxA, boxB):
    # box: [xmin, ymin, xmax, ymax]
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[2], boxB[2])
    yB = min(boxA[3], boxB[3])
    interArea = max(0, xB - xA) * max(0, yB - yA)
    boxAArea = (boxA[2]-boxA[0]) * (boxA[3]-boxA[1])
    boxBArea = (boxB[2]-boxB[0]) * (boxB[3]-boxB[1])
    iou = interArea / (boxAArea + boxBArea - interArea)
    return iou

def get_gt_boxes(target):
    """Извлекает все bounding boxes из аннотации VOC."""
    boxes = []
    if 'annotation' in target:
        objects = target['annotation']['object']
        if not isinstance(objects, list):
            objects = [objects]
        for obj in objects:
            bbox = obj['bndbox']
            boxes.append([int(bbox['xmin']), int(bbox['ymin']), int(bbox['xmax']), int(bbox['ymax'])])
    return np.array(boxes) if boxes else np.empty((0,4))

def compute_metrics(model, dataset, score_threshold=0.5, iou_threshold=0.5, device='cpu', max_samples=None):
    tp = 0
    fp = 0
    fn = 0
    total_iou = 0
    matched = 0
    indices = range(len(dataset)) if max_samples is None else range(min(max_samples, len(dataset)))
    for idx in tqdm(indices, desc=f"Computing metrics (th={score_threshold})"):
        img, target = dataset[idx]
        img_tensor = transforms.ToTensor()(img).unsqueeze(0).to(device)
        with torch.no_grad():
            pred = model(img_tensor)[0]
        # Предсказанные боксы с уверенностью выше порога
        keep = pred['scores'] > score_threshold
        pred_boxes = pred['boxes'][keep].cpu().numpy()
        # GT боксы
        gt_boxes = get_gt_boxes(target)

        # Простой greedy match
        matched_gt = set()
        for pb in pred_boxes:
            best_iou = 0
            best_idx = -1
            for j, gb in enumerate(gt_boxes):
                iou = compute_iou(pb, gb)
                if iou > best_iou:
                    best_iou = iou
                    best_idx = j
            if best_iou >= iou_threshold and best_idx not in matched_gt:
                tp += 1
                matched_gt.add(best_idx)
                total_iou += best_iou
                matched += 1
            else:
                fp += 1
        fn += len(gt_boxes) - len(matched_gt)

    precision = tp / (tp + fp) if (tp+fp) > 0 else 0
    recall = tp / (tp + fn) if (tp+fn) > 0 else 0
    mean_iou = total_iou / matched if matched > 0 else 0
    return precision, recall, mean_iou


# #### 3.3. Оценка для V1 и V2


# Используем небольшую часть validation для ускорения (опционально)
max_samples = 50  # Можно увеличить, но дольше

# V1: threshold = 0.3
prec1, rec1, miou1 = compute_metrics(model_det, val_det, score_threshold=0.3, device=device, max_samples=max_samples)
print(f"V1 (th=0.3): Precision={prec1:.4f}, Recall={rec1:.4f}, mIoU={miou1:.4f}")

# V2: threshold = 0.7
prec2, rec2, miou2 = compute_metrics(model_det, val_det, score_threshold=0.7, device=device, max_samples=max_samples)
print(f"V2 (th=0.7): Precision={prec2:.4f}, Recall={rec2:.4f}, mIoU={miou2:.4f}")


# #### 3.4. Визуализация предсказаний


def visualize_detections(model, dataset, idx, thresholds=[0.3, 0.7], device='cpu'):
    img, target = dataset[idx]
    img_tensor = transforms.ToTensor()(img).unsqueeze(0).to(device)
    with torch.no_grad():
        pred = model(img_tensor)[0]

    fig, axes = plt.subplots(1, len(thresholds)+1, figsize=(15,5))
    # GT
    axes[0].imshow(img)
    axes[0].set_title('Ground Truth')
    gt_boxes = get_gt_boxes(target)
    for box in gt_boxes:
        rect = plt.Rectangle((box[0], box[1]), box[2]-box[0], box[3]-box[1],
                             fill=False, edgecolor='green', linewidth=2)
        axes[0].add_patch(rect)
    axes[0].axis('off')

    for i, th in enumerate(thresholds):
        keep = pred['scores'] > th
        boxes = pred['boxes'][keep].cpu().numpy()
        scores = pred['scores'][keep].cpu().numpy()
        axes[i+1].imshow(img)
        axes[i+1].set_title(f'Predictions (th={th})')
        for box, score in zip(boxes, scores):
            rect = plt.Rectangle((box[0], box[1]), box[2]-box[0], box[3]-box[1],
                                 fill=False, edgecolor='red', linewidth=2)
            axes[i+1].add_patch(rect)
            axes[i+1].text(box[0], box[1]-5, f'{score:.2f}', color='red', fontsize=8)
        axes[i+1].axis('off')
    plt.tight_layout()
    return fig

# Визуализируем несколько примеров
example_indices = [0, 10, 20]
for idx in example_indices:
    fig = visualize_detections(model_det, val_det, idx, thresholds=[0.3, 0.7], device=device)
    plt.show()

# Сохраняем примеры в файл
fig, axes = plt.subplots(len(example_indices), 3, figsize=(15, 4*len(example_indices)))
for row, idx in enumerate(example_indices):
    img, target = val_det[idx]
    img_tensor = transforms.ToTensor()(img).unsqueeze(0).to(device)
    with torch.no_grad():
        pred = model_det(img_tensor)[0]

    # GT
    axes[row,0].imshow(img)
    axes[row,0].set_title('Ground Truth')
    gt_boxes = get_gt_boxes(target)
    for box in gt_boxes:
        rect = plt.Rectangle((box[0], box[1]), box[2]-box[0], box[3]-box[1],
                             fill=False, edgecolor='green', linewidth=2)
        axes[row,0].add_patch(rect)
    axes[row,0].axis('off')

    # Pred th=0.3
    keep = pred['scores'] > 0.3
    boxes = pred['boxes'][keep].cpu().numpy()
    scores = pred['scores'][keep].cpu().numpy()
    axes[row,1].imshow(img)
    axes[row,1].set_title('th=0.3')
    for box, score in zip(boxes, scores):
        rect = plt.Rectangle((box[0], box[1]), box[2]-box[0], box[3]-box[1],
                             fill=False, edgecolor='red', linewidth=2)
        axes[row,1].add_patch(rect)
        axes[row,1].text(box[0], box[1]-5, f'{score:.2f}', color='red', fontsize=8)
    axes[row,1].axis('off')

    # Pred th=0.7
    keep = pred['scores'] > 0.7
    boxes = pred['boxes'][keep].cpu().numpy()
    scores = pred['scores'][keep].cpu().numpy()
    axes[row,2].imshow(img)
    axes[row,2].set_title('th=0.7')
    for box, score in zip(boxes, scores):
        rect = plt.Rectangle((box[0], box[1]), box[2]-box[0], box[3]-box[1],
                             fill=False, edgecolor='red', linewidth=2)
        axes[row,2].add_patch(rect)
        axes[row,2].text(box[0], box[1]-5, f'{score:.2f}', color='red', fontsize=8)
    axes[row,2].axis('off')

plt.tight_layout()
plt.savefig("artifacts/figures/detection_examples.png")
plt.show()


# #### 3.5. Сохранение метрик детекции в runs.csv


det_results = [
    {
        "experiment_id": "V1",
        "task": "detection",
        "dataset": "VOC2012",
        "seed": seed,
        "model_summary": "FasterRCNN_ResNet50_FPN",
        "optimizer": None,
        "lr": None,
        "epochs_trained": None,
        "best_val_accuracy": None,
        "test_accuracy": None,
        "precision": prec1,
        "recall": rec1,
        "mean_iou": miou1,
        "notes": f"score_threshold=0.3, IoU_threshold=0.5, samples={max_samples}"
    },
    {
        "experiment_id": "V2",
        "task": "detection",
        "dataset": "VOC2012",
        "seed": seed,
        "model_summary": "FasterRCNN_ResNet50_FPN",
        "optimizer": None,
        "lr": None,
        "epochs_trained": None,
        "best_val_accuracy": None,
        "test_accuracy": None,
        "precision": prec2,
        "recall": rec2,
        "mean_iou": miou2,
        "notes": f"score_threshold=0.7, IoU_threshold=0.5, samples={max_samples}"
    }
]

# Добавляем к ранее сохранённым результатам классификации
df_results = pd.concat([df_results, pd.DataFrame(det_results)], ignore_index=True)
df_results.to_csv("artifacts/runs.csv", index=False)


# #### 3.6. Визуализация сравнения метрик


labels = ['Precision', 'Recall', 'mean IoU']
v1_vals = [prec1, rec1, miou1]
v2_vals = [prec2, rec2, miou2]
x = np.arange(len(labels))
width = 0.35
fig, ax = plt.subplots()
ax.bar(x - width/2, v1_vals, width, label='V1 (th=0.3)')
ax.bar(x + width/2, v2_vals, width, label='V2 (th=0.7)')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
plt.title('Detection metrics comparison')
plt.savefig("artifacts/figures/detection_metrics.png")
plt.show()


# ### 4. Завершение
# Все артефакты сохранены в папку `artifacts/`. Ноутбук готов к сдаче.
# Out:
# Using device: cuda
# 100%|██████████| 169M/169M [00:45<00:00, 3.71MB/s]
# CNN train batch shape: torch.Size([64, 3, 32, 32]), labels: torch.Size([64])
# Training: 100%|██████████| 625/625 [00:14<00:00, 43.74it/s]
# Evaluating: 100%|██████████| 157/157 [00:09<00:00, 16.21it/s]
# Epoch 1: train_loss=3.8702, train_acc=0.1065, val_loss=3.3055, val_acc=0.2034
# Training: 100%|██████████| 625/625 [00:14<00:00, 42.31it/s]
# Evaluating: 100%|██████████| 157/157 [00:12<00:00, 12.65it/s]
# Epoch 2: train_loss=3.1696, train_acc=0.2225, val_loss=2.8210, val_acc=0.2969
# Training: 100%|██████████| 625/625 [00:17<00:00, 36.20it/s]
# Evaluating: 100%|██████████| 157/157 [00:13<00:00, 11.48it/s]
# Epoch 3: train_loss=2.8383, train_acc=0.2880, val_loss=2.6113, val_acc=0.3335
# Training: 100%|██████████| 625/625 [00:18<00:00, 34.31it/s]
# Evaluating: 100%|██████████| 157/157 [00:13<00:00, 11.48it/s]
# Epoch 4: train_loss=2.5976, train_acc=0.3307, val_loss=2.4751, val_acc=0.3619
# Training: 100%|██████████| 625/625 [00:16<00:00, 36.79it/s]
# Evaluating: 100%|██████████| 157/157 [00:11<00:00, 14.12it/s]
# Epoch 5: train_loss=2.4030, train_acc=0.3713, val_loss=2.3770, val_acc=0.3800
# Training: 100%|██████████| 625/625 [00:16<00:00, 38.56it/s]
# Evaluating: 100%|██████████| 157/157 [00:11<00:00, 13.86it/s]
# Epoch 6: train_loss=2.2415, train_acc=0.4045, val_loss=2.3051, val_acc=0.4034
# Training: 100%|██████████| 625/625 [00:16<00:00, 38.88it/s]
# Evaluating: 100%|██████████| 157/157 [00:11<00:00, 14.20it/s]
# Epoch 7: train_loss=2.1010, train_acc=0.4340, val_loss=2.2751, val_acc=0.4064
# Training: 100%|██████████| 625/625 [00:15<00:00, 40.01it/s]
# Evaluating: 100%|██████████| 157/157 [00:10<00:00, 15.24it/s]
# Epoch 8: train_loss=1.9738, train_acc=0.4626, val_loss=2.2404, val_acc=0.4178
# Training: 100%|██████████| 625/625 [00:14<00:00, 43.09it/s]
# Evaluating: 100%|██████████| 157/157 [00:11<00:00, 14.03it/s]
# Epoch 9: train_loss=1.8645, train_acc=0.4858, val_loss=2.2073, val_acc=0.4303
# Training: 100%|██████████| 625/625 [00:16<00:00, 36.88it/s]
# Evaluating: 100%|██████████| 157/157 [00:10<00:00, 14.88it/s]
# Epoch 10: train_loss=1.7653, train_acc=0.5068, val_loss=2.2464, val_acc=0.4236
# Training: 100%|██████████| 625/625 [00:15<00:00, 41.18it/s]
# Evaluating: 100%|██████████| 157/157 [00:10<00:00, 14.73it/s]
# Epoch 11: train_loss=1.6568, train_acc=0.5315, val_loss=2.2387, val_acc=0.4233
# Training: 100%|██████████| 625/625 [00:15<00:00, 41.06it/s]
# Evaluating: 100%|██████████| 157/157 [00:10<00:00, 14.33it/s]
# Epoch 12: train_loss=1.5769, train_acc=0.5505, val_loss=2.3164, val_acc=0.4225
# Training: 100%|██████████| 625/625 [00:14<00:00, 42.84it/s]
# Evaluating: 100%|██████████| 157/157 [00:10<00:00, 14.94it/s]
# Epoch 13: train_loss=1.4901, train_acc=0.5714, val_loss=2.3195, val_acc=0.4260
# Training: 100%|██████████| 625/625 [00:14<00:00, 43.99it/s]
# Evaluating: 100%|██████████| 157/157 [00:09<00:00, 15.80it/s]
# Epoch 14: train_loss=1.4142, train_acc=0.5904, val_loss=2.3606, val_acc=0.4265
# Training: 100%|██████████| 625/625 [00:14<00:00, 42.68it/s]
# Evaluating: 100%|██████████| 157/157 [00:10<00:00, 14.70it/s]
# Epoch 15: train_loss=1.3450, train_acc=0.6029, val_loss=2.4093, val_acc=0.4271
# Training: 100%|██████████| 625/625 [00:13<00:00, 45.53it/s]
# Evaluating: 100%|██████████| 157/157 [00:10<00:00, 14.94it/s]
# Epoch 16: train_loss=1.2879, train_acc=0.6167, val_loss=2.4326, val_acc=0.4212
# Training: 100%|██████████| 625/625 [00:15<00:00, 41.42it/s]
# Evaluating: 100%|██████████| 157/157 [00:10<00:00, 14.90it/s]
# Epoch 17: train_loss=1.2351, train_acc=0.6326, val_loss=2.4377, val_acc=0.4266
# Training: 100%|██████████| 625/625 [00:15<00:00, 39.43it/s]
# Evaluating: 100%|██████████| 157/157 [00:11<00:00, 13.81it/s]
# Epoch 18: train_loss=1.1685, train_acc=0.6490, val_loss=2.5725, val_acc=0.4204
# Training: 100%|██████████| 625/625 [00:15<00:00, 40.93it/s]
# Evaluating: 100%|██████████| 157/157 [00:11<00:00, 13.87it/s]
# Epoch 19: train_loss=1.1193, train_acc=0.6586, val_loss=2.6022, val_acc=0.4255
# Training: 100%|██████████| 625/625 [00:14<00:00, 41.75it/s]
# Evaluating: 100%|██████████| 157/157 [00:10<00:00, 15.09it/s]
# Epoch 20: train_loss=1.0813, train_acc=0.6739, val_loss=2.6587, val_acc=0.4212
# C1 best val acc: 0.4303
# Training: 100%|██████████| 625/625 [00:27<00:00, 22.47it/s]
# Evaluating: 100%|██████████| 157/157 [00:10<00:00, 15.35it/s]
# Epoch 1: train_loss=4.1025, train_acc=0.0683, val_loss=3.6012, val_acc=0.1424
# Training: 100%|██████████| 625/625 [00:27<00:00, 23.11it/s]
# Evaluating: 100%|██████████| 157/157 [00:10<00:00, 15.21it/s]
# Epoch 2: train_loss=3.6411, train_acc=0.1376, val_loss=3.2109, val_acc=0.2093
# Training: 100%|██████████| 625/625 [00:28<00:00, 21.78it/s]
# Evaluating: 100%|██████████| 157/157 [00:12<00:00, 12.08it/s]
# Epoch 3: train_loss=3.3941, train_acc=0.1814, val_loss=2.9853, val_acc=0.2630
# Training: 100%|██████████| 625/625 [00:34<00:00, 18.30it/s]
# Evaluating: 100%|██████████| 157/157 [00:11<00:00, 13.31it/s]
# Epoch 4: train_loss=3.2345, train_acc=0.2126, val_loss=2.8350, val_acc=0.2897
# Training: 100%|██████████| 625/625 [00:31<00:00, 20.06it/s]
# Evaluating: 100%|██████████| 157/157 [00:11<00:00, 14.11it/s]
# Epoch 5: train_loss=3.1106, train_acc=0.2339, val_loss=2.7360, val_acc=0.3119
# Training: 100%|██████████| 625/625 [00:28<00:00, 21.65it/s]
# Evaluating: 100%|██████████| 157/157 [00:10<00:00, 14.63it/s]
# Epoch 6: train_loss=2.9912, train_acc=0.2566, val_loss=2.5782, val_acc=0.3381
# Training: 100%|██████████| 625/625 [00:27<00:00, 22.41it/s]
# Evaluating: 100%|██████████| 157/157 [00:09<00:00, 16.37it/s]
# Epoch 7: train_loss=2.9112, train_acc=0.2708, val_loss=2.5225, val_acc=0.3607
# Training: 100%|██████████| 625/625 [00:24<00:00, 25.47it/s]
# Evaluating: 100%|██████████| 157/157 [00:09<00:00, 16.85it/s]
# Epoch 8: train_loss=2.8423, train_acc=0.2863, val_loss=2.4931, val_acc=0.3628
# Training: 100%|██████████| 625/625 [00:24<00:00, 25.24it/s]
# Evaluating: 100%|██████████| 157/157 [00:09<00:00, 16.83it/s]
# Epoch 9: train_loss=2.7769, train_acc=0.2981, val_loss=2.3764, val_acc=0.3805
# Training: 100%|██████████| 625/625 [00:24<00:00, 25.63it/s]
# Evaluating: 100%|██████████| 157/157 [00:09<00:00, 16.35it/s]
# Epoch 10: train_loss=2.7302, train_acc=0.3079, val_loss=2.3838, val_acc=0.3869
# Training: 100%|██████████| 625/625 [00:26<00:00, 23.30it/s]
# Evaluating: 100%|██████████| 157/157 [00:09<00:00, 15.89it/s]
# Epoch 11: train_loss=2.6896, train_acc=0.3145, val_loss=2.3675, val_acc=0.3886
# Training: 100%|██████████| 625/625 [00:27<00:00, 22.99it/s]
# Evaluating: 100%|██████████| 157/157 [00:10<00:00, 14.92it/s]
# Epoch 12: train_loss=2.6468, train_acc=0.3261, val_loss=2.2872, val_acc=0.4048
# Training: 100%|██████████| 625/625 [00:26<00:00, 23.75it/s]
# Evaluating: 100%|██████████| 157/157 [00:09<00:00, 16.80it/s]
# Epoch 13: train_loss=2.6173, train_acc=0.3300, val_loss=2.2487, val_acc=0.4141
# Training: 100%|██████████| 625/625 [00:24<00:00, 25.16it/s]
# Evaluating: 100%|██████████| 157/157 [00:09<00:00, 15.81it/s]
# Epoch 14: train_loss=2.5878, train_acc=0.3352, val_loss=2.2483, val_acc=0.4146
# Training: 100%|██████████| 625/625 [00:27<00:00, 22.37it/s]
# Evaluating: 100%|██████████| 157/157 [00:09<00:00, 16.00it/s]
# Epoch 15: train_loss=2.5488, train_acc=0.3461, val_loss=2.2080, val_acc=0.4258
# Training: 100%|██████████| 625/625 [00:25<00:00, 24.86it/s]
# Evaluating: 100%|██████████| 157/157 [00:09<00:00, 15.76it/s]
# Epoch 16: train_loss=2.5273, train_acc=0.3473, val_loss=2.1732, val_acc=0.4238
# Training: 100%|██████████| 625/625 [00:27<00:00, 22.33it/s]
# Evaluating: 100%|██████████| 157/157 [00:10<00:00, 14.90it/s]
# Epoch 17: train_loss=2.4965, train_acc=0.3543, val_loss=2.1744, val_acc=0.4308
# Training: 100%|██████████| 625/625 [00:27<00:00, 22.99it/s]
# Evaluating: 100%|██████████| 157/157 [00:11<00:00, 13.11it/s]
# Epoch 18: train_loss=2.4716, train_acc=0.3625, val_loss=2.1409, val_acc=0.4342
# Training: 100%|██████████| 625/625 [00:27<00:00, 22.61it/s]
# Evaluating: 100%|██████████| 157/157 [00:11<00:00, 13.42it/s]
# Epoch 19: train_loss=2.4548, train_acc=0.3619, val_loss=2.2005, val_acc=0.4207
# Training: 100%|██████████| 625/625 [00:33<00:00, 18.58it/s]
# Evaluating: 100%|██████████| 157/157 [00:11<00:00, 13.24it/s]
# c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 20: train_loss=2.4308, train_acc=0.3682, val_loss=2.1300, val_acc=0.4378
# C2 best val acc: 0.4378
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to C:\Users\user/.cache\torch\hub\checkpoints\resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:04<00:00, 11.5MB/s]
# Training: 100%|██████████| 625/625 [01:07<00:00,  9.28it/s]
# Evaluating: 100%|██████████| 157/157 [00:24<00:00,  6.29it/s]
# Epoch 1: train_loss=2.5118, train_acc=0.4034, val_loss=1.8066, val_acc=0.5279
# Training: 100%|██████████| 625/625 [01:09<00:00,  9.05it/s]
# Evaluating: 100%|██████████| 157/157 [00:21<00:00,  7.21it/s]
# Epoch 2: train_loss=1.6550, train_acc=0.5593, val_loss=1.6217, val_acc=0.5565
# Training: 100%|██████████| 625/625 [01:10<00:00,  8.90it/s]
# Evaluating: 100%|██████████| 157/157 [00:23<00:00,  6.82it/s]
# Epoch 3: train_loss=1.4957, train_acc=0.5907, val_loss=1.5871, val_acc=0.5664
# Training: 100%|██████████| 625/625 [01:07<00:00,  9.22it/s]
# Evaluating: 100%|██████████| 157/157 [00:22<00:00,  7.00it/s]
# Epoch 4: train_loss=1.4064, train_acc=0.6117, val_loss=1.5765, val_acc=0.5672
# Training: 100%|██████████| 625/625 [01:17<00:00,  8.02it/s]
# Evaluating: 100%|██████████| 157/157 [00:22<00:00,  7.02it/s]
# Epoch 5: train_loss=1.3507, train_acc=0.6238, val_loss=1.5782, val_acc=0.5629
# Training: 100%|██████████| 625/625 [01:06<00:00,  9.42it/s]
# Evaluating: 100%|██████████| 157/157 [00:22<00:00,  7.00it/s]
# Epoch 6: train_loss=1.3066, train_acc=0.6342, val_loss=1.5523, val_acc=0.5728
# Training: 100%|██████████| 625/625 [01:06<00:00,  9.43it/s]
# Evaluating: 100%|██████████| 157/157 [00:22<00:00,  7.01it/s]
# Epoch 7: train_loss=1.2751, train_acc=0.6405, val_loss=1.5418, val_acc=0.5724
# Training: 100%|██████████| 625/625 [01:06<00:00,  9.39it/s]
# Evaluating: 100%|██████████| 157/157 [00:22<00:00,  6.97it/s]
# Epoch 8: train_loss=1.2472, train_acc=0.6469, val_loss=1.5559, val_acc=0.5738
# Training: 100%|██████████| 625/625 [01:06<00:00,  9.37it/s]
# Evaluating: 100%|██████████| 157/157 [00:22<00:00,  6.95it/s]
# Epoch 9: train_loss=1.2219, train_acc=0.6532, val_loss=1.5515, val_acc=0.5730
# Training: 100%|██████████| 625/625 [01:06<00:00,  9.38it/s]
# Evaluating: 100%|██████████| 157/157 [00:22<00:00,  6.93it/s]
# Epoch 10: train_loss=1.2015, train_acc=0.6597, val_loss=1.5711, val_acc=0.5707
# Training: 100%|██████████| 625/625 [01:06<00:00,  9.41it/s]
# Evaluating: 100%|██████████| 157/157 [00:22<00:00,  7.00it/s]
# Epoch 11: train_loss=1.1798, train_acc=0.6630, val_loss=1.5584, val_acc=0.5754
# Training: 100%|██████████| 625/625 [01:06<00:00,  9.34it/s]
# Evaluating: 100%|██████████| 157/157 [00:22<00:00,  7.00it/s]
# Epoch 12: train_loss=1.1664, train_acc=0.6669, val_loss=1.5672, val_acc=0.5698
# Training: 100%|██████████| 625/625 [01:07<00:00,  9.29it/s]
# Evaluating: 100%|██████████| 157/157 [00:31<00:00,  5.01it/s]
# Epoch 13: train_loss=1.1507, train_acc=0.6707, val_loss=1.5811, val_acc=0.5735
# Training: 100%|██████████| 625/625 [01:24<00:00,  7.43it/s]
# Evaluating: 100%|██████████| 157/157 [00:26<00:00,  5.93it/s]
# Epoch 14: train_loss=1.1407, train_acc=0.6710, val_loss=1.5891, val_acc=0.5737
# Training: 100%|██████████| 625/625 [01:20<00:00,  7.77it/s]
# Evaluating: 100%|██████████| 157/157 [00:26<00:00,  5.93it/s]
# Epoch 15: train_loss=1.1323, train_acc=0.6744, val_loss=1.5889, val_acc=0.5743
# Training: 100%|██████████| 625/625 [01:20<00:00,  7.73it/s]
# Evaluating: 100%|██████████| 157/157 [00:26<00:00,  5.89it/s]
# Epoch 16: train_loss=1.1213, train_acc=0.6769, val_loss=1.6092, val_acc=0.5688
# Training: 100%|██████████| 625/625 [01:20<00:00,  7.76it/s]
# Evaluating: 100%|██████████| 157/157 [00:26<00:00,  5.89it/s]
# Epoch 17: train_loss=1.1109, train_acc=0.6786, val_loss=1.6077, val_acc=0.5734
# Training: 100%|██████████| 625/625 [01:20<00:00,  7.79it/s]
# Evaluating: 100%|██████████| 157/157 [00:26<00:00,  5.94it/s]
# Epoch 18: train_loss=1.1009, train_acc=0.6826, val_loss=1.6017, val_acc=0.5727
# Training: 100%|██████████| 625/625 [01:23<00:00,  7.45it/s]
# Evaluating: 100%|██████████| 157/157 [00:24<00:00,  6.45it/s]
# Epoch 19: train_loss=1.0904, train_acc=0.6863, val_loss=1.6087, val_acc=0.5745
# Training: 100%|██████████| 625/625 [01:18<00:00,  8.00it/s]
# Evaluating: 100%|██████████| 157/157 [00:24<00:00,  6.32it/s]
# Epoch 20: train_loss=1.0861, train_acc=0.6835, val_loss=1.6089, val_acc=0.5761
# C3 best val acc: 0.5761
# Training: 100%|██████████| 625/625 [01:35<00:00,  6.51it/s]
# Evaluating: 100%|██████████| 157/157 [00:26<00:00,  5.99it/s]
# Epoch 1: train_loss=1.7196, train_acc=0.5252, val_loss=1.3278, val_acc=0.6147
# Training: 100%|██████████| 625/625 [01:30<00:00,  6.94it/s]
# Evaluating: 100%|██████████| 157/157 [00:26<00:00,  5.88it/s]
# Epoch 2: train_loss=0.9463, train_acc=0.7183, val_loss=1.2899, val_acc=0.6356
# Training: 100%|██████████| 625/625 [01:29<00:00,  7.00it/s]
# Evaluating: 100%|██████████| 157/157 [00:25<00:00,  6.17it/s]
# Epoch 3: train_loss=0.5288, train_acc=0.8365, val_loss=1.2922, val_acc=0.6608
# Training: 100%|██████████| 625/625 [01:27<00:00,  7.17it/s]
# Evaluating: 100%|██████████| 157/157 [00:28<00:00,  5.42it/s]
# Epoch 4: train_loss=0.2874, train_acc=0.9092, val_loss=1.4297, val_acc=0.6532
# Training: 100%|██████████| 625/625 [01:30<00:00,  6.92it/s]
# Evaluating: 100%|██████████| 157/157 [00:24<00:00,  6.37it/s]
# Epoch 5: train_loss=0.1874, train_acc=0.9410, val_loss=1.5057, val_acc=0.6532
# Training: 100%|██████████| 625/625 [01:29<00:00,  6.98it/s]
# Evaluating: 100%|██████████| 157/157 [00:23<00:00,  6.55it/s]
# Epoch 6: train_loss=0.1453, train_acc=0.9538, val_loss=1.6605, val_acc=0.6461
# Training: 100%|██████████| 625/625 [01:17<00:00,  8.05it/s]
# Evaluating: 100%|██████████| 157/157 [00:26<00:00,  5.98it/s]
# Epoch 7: train_loss=0.1327, train_acc=0.9584, val_loss=1.7447, val_acc=0.6417
# Training: 100%|██████████| 625/625 [01:24<00:00,  7.41it/s]
# Evaluating: 100%|██████████| 157/157 [00:22<00:00,  7.01it/s]
# Epoch 8: train_loss=0.1188, train_acc=0.9618, val_loss=1.8596, val_acc=0.6430
# Training: 100%|██████████| 625/625 [01:23<00:00,  7.51it/s]
# Evaluating: 100%|██████████| 157/157 [00:24<00:00,  6.45it/s]
# Epoch 9: train_loss=0.1042, train_acc=0.9660, val_loss=1.8249, val_acc=0.6573
# Training: 100%|██████████| 625/625 [02:02<00:00,  5.10it/s]
# Evaluating: 100%|██████████| 157/157 [00:30<00:00,  5.10it/s]
# Epoch 10: train_loss=0.0875, train_acc=0.9719, val_loss=1.8477, val_acc=0.6590
# Training: 100%|██████████| 625/625 [01:46<00:00,  5.88it/s]
# Evaluating: 100%|██████████| 157/157 [00:26<00:00,  5.82it/s]
# Epoch 11: train_loss=0.0902, train_acc=0.9712, val_loss=1.9634, val_acc=0.6479
# Training: 100%|██████████| 625/625 [01:32<00:00,  6.73it/s]
# Evaluating: 100%|██████████| 157/157 [00:23<00:00,  6.66it/s]
# Epoch 12: train_loss=0.0881, train_acc=0.9729, val_loss=1.9805, val_acc=0.6536
# Training: 100%|██████████| 625/625 [01:22<00:00,  7.53it/s]
# Evaluating: 100%|██████████| 157/157 [00:23<00:00,  6.63it/s]
# Epoch 13: train_loss=0.0772, train_acc=0.9749, val_loss=2.1302, val_acc=0.6435
# Training: 100%|██████████| 625/625 [01:22<00:00,  7.62it/s]
# Evaluating: 100%|██████████| 157/157 [00:23<00:00,  6.78it/s]
# Epoch 14: train_loss=0.0661, train_acc=0.9791, val_loss=1.9750, val_acc=0.6633
# Training: 100%|██████████| 625/625 [01:33<00:00,  6.66it/s]
# Evaluating: 100%|██████████| 157/157 [00:29<00:00,  5.24it/s]
# Epoch 15: train_loss=0.0719, train_acc=0.9775, val_loss=2.1145, val_acc=0.6472
# Training: 100%|██████████| 625/625 [01:26<00:00,  7.26it/s]
# Evaluating: 100%|██████████| 157/157 [00:22<00:00,  7.08it/s]
# Epoch 16: train_loss=0.0796, train_acc=0.9747, val_loss=2.1003, val_acc=0.6537
# Training: 100%|██████████| 625/625 [01:20<00:00,  7.72it/s]
# Evaluating: 100%|██████████| 157/157 [00:22<00:00,  7.08it/s]
# Epoch 17: train_loss=0.0565, train_acc=0.9821, val_loss=2.1355, val_acc=0.6541
# Training: 100%|██████████| 625/625 [01:17<00:00,  8.06it/s]
# Evaluating: 100%|██████████| 157/157 [00:22<00:00,  7.13it/s]
# Epoch 18: train_loss=0.0612, train_acc=0.9805, val_loss=2.1584, val_acc=0.6544
# Training: 100%|██████████| 625/625 [01:22<00:00,  7.59it/s]
# Evaluating: 100%|██████████| 157/157 [00:23<00:00,  6.78it/s]
# Epoch 19: train_loss=0.0569, train_acc=0.9823, val_loss=2.2094, val_acc=0.6554
# Training: 100%|██████████| 625/625 [01:20<00:00,  7.73it/s]
# Evaluating: 100%|██████████| 157/157 [00:23<00:00,  6.56it/s]
# c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Epoch 20: train_loss=0.0524, train_acc=0.9838, val_loss=2.2055, val_acc=0.6585
# C4 best val acc: 0.6633
# Best model: C4 with val_acc = 0.6633
# Evaluating: 100%|██████████| 157/157 [00:21<00:00,  7.45it/s]
# Test accuracy of best model: 0.6682
# c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=FasterRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to C:\Users\user/.cache\torch\hub\checkpoints\fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# 100%|██████████| 160M/160M [00:15<00:00, 11.0MB/s]
# 100%|██████████| 2.00G/2.00G [10:24<00:00, 3.20MB/s]
